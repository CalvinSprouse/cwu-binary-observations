# %%
# imports
# %matplotlib inline
import lightkurve as lk

# %%
search_result = lk.search_targetpixelfile('44 Boo')
search_result
# Out:
# SearchResult containing 16 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 16 2019      SPOC     120   283819432      0.0
#   1 TESS Sector 16 2019      SPOC     120  1102093577      0.0
#   2 TESS Sector 16 2019 TESS-SPOC    1800   283819432      0.0
#   3 TESS Sector 16 2019 TESS-SPOC    1800  1102093577      0.0
#   4 TESS Sector 23 2020      SPOC     120   283819432      0.0
#   5 TESS Sector 23 2020      SPOC     120  1102093577      0.0
#   6 TESS Sector 23 2020 TESS-SPOC    1800   283819432      0.0
#   7 TESS Sector 23 2020 TESS-SPOC    1800  1102093577      0.0
#   8 TESS Sector 24 2020      SPOC     120   283819432      0.0
#   9 TESS Sector 24 2020      SPOC     120  1102093577      0.0
#  10 TESS Sector 24 2020 TESS-SPOC    1800   283819432      0.0
# ...

# %%
lcf = search_result[13].download()

# %%
lc = lcf.to_lightcurve()

# %%
lc.plot()
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>
